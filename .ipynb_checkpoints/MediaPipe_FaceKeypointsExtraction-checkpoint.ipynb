# %%
import os
import traceback

import pandas as pd
import numpy as np
import cv2
import mediapipe as mp

# for audio / video extraction, conversion:
import moviepy.editor as moviepyEditor

from matplotlib import pyplot as plt
import numpy as np


#------------------------------------------------------------------------------------
def extract_audio_from_video(video_path):  # , save_mp3_audio_as):
    
    # define clip from path:
    clip = moviepyEditor.VideoFileClip(video_path)
    
    # extract audio:
    return clip.audio.to_soundarray()
    # clip.audio.write_audiofile(save_mp3_audio_as)
    

#------------------------------------------------------------------------------------
# run through single video:
def process_video(video_path, class_name, webcam=False, verbose=False):
    
    detected_keypoints_coordinates = []
    
    #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
    # Media Pipe Initialization:
    mp_drawing = mp.solutions.drawing_utils
    mp_drawing_styles = mp.solutions.drawing_styles
    mp_face_mesh = mp.solutions.face_mesh
    #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
    
    print("\n----------------------\nVideo Capture Path:", video_path)
    
    # For webcam input:
    drawing_spec = mp_drawing.DrawingSpec(thickness=1, circle_radius=1)
    cap = cv2.VideoCapture(video_path)
    with mp_face_mesh.FaceMesh(
        max_num_faces=1,
        refine_landmarks=True,
        min_detection_confidence=0.5,
        min_tracking_confidence=0.5) as face_mesh:
        while cap.isOpened():
            success, image = cap.read()
            if not success:
                if webcam:
                    print("Ignoring empty camera frame.")
                    # If loading a video, use 'break' instead of 'continue'.
                    continue
                else:
                    break
            # To improve performance, optionally mark the image as not writeable to
            # pass by reference.
            image.flags.writeable = False
            image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            results = face_mesh.process(image)

            # Draw the face mesh annotations on the image.
            image.flags.writeable = True
            image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
            
            '''
            Collection of detected/tracked faces, where each face is represented as a list of 468 face landmarks and 
            each landmark is composed of x, y and z. x and y are normalized to [0.0, 1.0] by the image width and height 
            respectively. z represents the landmark depth with the depth at center of the head being the origin, 
            and the smaller the value the closer the landmark is to the camera. The magnitude of z uses roughly the same
            scale as x.
            '''
            if results.multi_face_landmarks:
                for face in results.multi_face_landmarks:
                    for landmark in face.landmark:
                        x = landmark.x
                        y = landmark.y
                        z = landmark.z

                        if verbose:
                            shape = image.shape 
                            relative_x = int(x * shape[1])
                            relative_y = int(y * shape[0])

                            cv2.circle(image, (relative_x, relative_y), radius=1, color=(225, 0, 100), thickness=1)
            else:
                # print(traceback.format_exc())
                x, y, z = 0.0, 0.0, 0.0
                
            
            # Append detected_keypoints_coordinates:
            detected_keypoints_coordinates.append([x,y,z])                
            
            if verbose:
                cv2.imshow('MediaPipe Face Mesh', cv2.flip(image, 1))
            
            if cv2.waitKey(1) & 0xFF == 27:
                break
    
    cap.release()
    cv2.destroyAllWindows()
    
    return np.array(detected_keypoints_coordinates)


#------------------------------------------------------------------------------------
def mkdir_if_none(directory):
    if not os.path.exists(directory):
        os.makedirs(directory)


#------------------------------------------------------------------------------------    
def save_label_data(class_num, sample_coordinates_data, sample_audio, save_as):
    
    class_label_npy = np.array([class_num])
    # sample_coordinates_data
    
    save_label_as = f"{save_as}_label.npy"
    save_coordinates_as = f"{save_as}_coord.npy"
    save_audio_as = f"{save_as}_audio.npy"
    
    np.save(save_label_as, class_label_npy)
    np.save(save_coordinates_as, sample_coordinates_data)
    np.save(save_audio_as, sample_audio)
    
    print("Saved with shape:")
    print("class_label_npy.shape:", class_label_npy.shape)
    print("sample_coordinates_data.shape:", sample_coordinates_data.shape)
    print("sample_audio.shape:", sample_audio.shape)
    

#------------------------------------------------------------------------------------
# run through all videos and collect - (1) face features and (2) audio features, and (3) save label reference if needed:
def train_data_preparation(video_data_dir="data/Video_chunks/Video_chunks",
                           csv_path="data/Video_chunks/Labels.xlsx",
                           class_to_num = {"truth": 0, "lie": 1},
                           num_to_class = {0: "truth", 1: "lie"},
                           save_keypoints_npy_to=os.path.join(os.getcwd(), "mediaPipe_keypoints_data")):
    
    mkdir_if_none(save_keypoints_npy_to)
    
    # read train data:
    csv_data = pd.read_excel(csv_path, sheet_name="All_Gestures_Deceptive and Trut")
    
    # go over each video and collect face features + audio features:
    for video_name in os.listdir(video_data_dir):
        # collect information about video:
        class_name = video_name.split("_")[1]
        class_num = class_to_num[class_name]
        video_path = os.path.join(video_data_dir, video_name)
        sample_name = video_name.split(".")[0]
        save_as = os.path.join(save_keypoints_npy_to, sample_name)
        
        # run through frames of current video:
        extracted_keypoints_npy = process_video(video_path=video_path, class_name=class_name, verbose=True)
        
        # extract audio:
        extracted_audio_npy = extract_audio_from_video(video_path=video_path)  # , save_mp3_audio_as="sample_audio.mp3")
        
        # save training sample:
        save_label_data(class_num=class_num, 
                        sample_coordinates_data=extracted_keypoints_npy, sample_audio=extracted_audio_npy, 
                        save_as=save_as)


# run video processing for (face & audio) feature collection:
train_data_preparation()
# Out:
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_001_000.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (126, 3)
# sample_audio.shape: (185661, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_001_001.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (117, 3)
# sample_audio.shape: (171990, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_001_002.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (117, 3)
# sample_audio.shape: (171990, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_001_003.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (126, 3)
# sample_audio.shape: (185661, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_001_004.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (24, 3)
# sample_audio.shape: (35280, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_002_000.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (126, 3)
# sample_audio.shape: (185661, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_002_001.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (117, 3)
# sample_audio.shape: (171990, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_002_002.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (117, 3)
# sample_audio.shape: (171990, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_002_003.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (126, 3)
# sample_audio.shape: (185661, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_002_004.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (117, 3)
# sample_audio.shape: (171990, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_002_005.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (117, 3)
# sample_audio.shape: (171990, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_002_006.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (126, 3)
# sample_audio.shape: (185661, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_002_007.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (117, 3)
# sample_audio.shape: (171990, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_002_008.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (116, 3)
# sample_audio.shape: (171108, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_002_009.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (126, 3)
# sample_audio.shape: (185661, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_002_010.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (117, 3)
# sample_audio.shape: (171990, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_002_011.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (117, 3)
# sample_audio.shape: (171990, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_002_012.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (126, 3)
# sample_audio.shape: (185661, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_002_013.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (117, 3)
# sample_audio.shape: (171990, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_002_014.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (117, 3)
# sample_audio.shape: (171990, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_002_015.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (75, 3)
# sample_audio.shape: (110690, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_003_000.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (126, 3)
# sample_audio.shape: (185661, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_003_001.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (86, 3)
# sample_audio.shape: (126567, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_004_000.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (126, 3)
# sample_audio.shape: (185661, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_004_001.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (117, 3)
# sample_audio.shape: (171990, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_004_002.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (106, 3)
# sample_audio.shape: (156114, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_005_000.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (126, 3)
# sample_audio.shape: (185661, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_005_001.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (117, 3)
# sample_audio.shape: (171990, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_005_002.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (117, 3)
# sample_audio.shape: (171990, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_005_003.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (126, 3)
# sample_audio.shape: (185661, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_005_004.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (117, 3)
# sample_audio.shape: (171990, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_005_005.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (117, 3)
# sample_audio.shape: (171990, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_005_006.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (126, 3)
# sample_audio.shape: (185661, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_005_007.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (117, 3)
# sample_audio.shape: (171990, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_005_008.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (116, 3)
# sample_audio.shape: (171108, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_005_009.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (126, 3)
# sample_audio.shape: (185661, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_005_010.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (117, 3)
# sample_audio.shape: (171990, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_005_011.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (117, 3)
# sample_audio.shape: (171990, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_005_012.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (126, 3)
# sample_audio.shape: (185661, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_005_013.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (37, 3)
# sample_audio.shape: (55125, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_006_000.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (126, 3)
# sample_audio.shape: (185661, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_006_001.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (117, 3)
# sample_audio.shape: (171990, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_006_002.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (117, 3)
# sample_audio.shape: (171990, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_006_003.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (126, 3)
# sample_audio.shape: (185661, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_006_004.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (60, 3)
# sample_audio.shape: (89082, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_007_000.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (126, 3)
# sample_audio.shape: (185661, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_007_001.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (117, 3)
# sample_audio.shape: (171990, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_007_002.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (117, 3)
# sample_audio.shape: (171990, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_007_003.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (126, 3)
# sample_audio.shape: (185661, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_007_004.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (117, 3)
# sample_audio.shape: (171990, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_007_005.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (117, 3)
# sample_audio.shape: (171990, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_007_006.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (126, 3)
# sample_audio.shape: (185661, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_007_007.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (117, 3)
# sample_audio.shape: (171990, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_007_008.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (116, 3)
# sample_audio.shape: (171108, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_007_009.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (126, 3)
# sample_audio.shape: (185661, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_007_010.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (117, 3)
# sample_audio.shape: (171990, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_007_011.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (81, 3)
# sample_audio.shape: (119070, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_008_000.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (126, 3)
# sample_audio.shape: (185661, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_008_001.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (93, 3)
# sample_audio.shape: (137151, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_009_000.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (126, 3)
# sample_audio.shape: (185661, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_009_001.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (117, 3)
# sample_audio.shape: (171990, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_009_002.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (117, 3)
# sample_audio.shape: (171990, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_009_003.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (126, 3)
# sample_audio.shape: (185661, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_009_004.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (117, 3)
# sample_audio.shape: (171990, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_009_005.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (16, 3)
# sample_audio.shape: (24255, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_010_000.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (126, 3)
# sample_audio.shape: (185661, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_010_001.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (117, 3)
# sample_audio.shape: (171990, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_010_002.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (117, 3)
# sample_audio.shape: (171990, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_010_003.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (126, 3)
# sample_audio.shape: (185661, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_010_004.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (117, 3)
# sample_audio.shape: (171990, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_010_005.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (117, 3)
# sample_audio.shape: (171990, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_010_006.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (126, 3)
# sample_audio.shape: (185661, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_010_007.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (30, 3)
# sample_audio.shape: (44982, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_011_000.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (126, 3)
# sample_audio.shape: (185661, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_011_001.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (117, 3)
# sample_audio.shape: (171990, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_011_002.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (117, 3)
# sample_audio.shape: (171990, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_011_003.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (126, 3)
# sample_audio.shape: (185661, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_011_004.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (117, 3)
# sample_audio.shape: (171990, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_011_005.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (117, 3)
# sample_audio.shape: (171990, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_011_006.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (126, 3)
# sample_audio.shape: (185661, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_011_007.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (117, 3)
# sample_audio.shape: (171990, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_011_008.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (47, 3)
# sample_audio.shape: (70119, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_012_000.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (126, 3)
# sample_audio.shape: (185661, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_012_001.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (111, 3)
# sample_audio.shape: (163170, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_013_000.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (126, 3)
# sample_audio.shape: (185661, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_013_001.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (117, 3)
# sample_audio.shape: (171990, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_013_002.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (117, 3)
# sample_audio.shape: (171990, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_013_003.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (126, 3)
# sample_audio.shape: (185661, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_013_004.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (85, 3)
# sample_audio.shape: (125685, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_014_000.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (126, 3)
# sample_audio.shape: (185661, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_014_001.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (117, 3)
# sample_audio.shape: (171990, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_014_002.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (117, 3)
# sample_audio.shape: (173313, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_014_003.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (90, 3)
# sample_audio.shape: (136710, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_015_000.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (126, 3)
# sample_audio.shape: (185661, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_015_001.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (117, 3)
# sample_audio.shape: (171990, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_015_002.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (117, 3)
# sample_audio.shape: (171990, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_015_003.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (126, 3)
# sample_audio.shape: (185661, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_015_004.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (117, 3)
# sample_audio.shape: (171990, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_015_005.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (117, 3)
# sample_audio.shape: (171990, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_015_006.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (126, 3)
# sample_audio.shape: (185661, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_015_007.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (117, 3)
# sample_audio.shape: (171990, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_015_008.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (89, 3)
# sample_audio.shape: (135828, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_016_000.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (126, 3)
# sample_audio.shape: (185661, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_016_001.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (117, 3)
# sample_audio.shape: (171990, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_016_002.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (117, 3)
# sample_audio.shape: (171990, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_016_003.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (126, 3)
# sample_audio.shape: (185661, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_016_004.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (117, 3)
# sample_audio.shape: (173313, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_016_005.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (117, 3)
# sample_audio.shape: (171990, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_016_006.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (126, 3)
# sample_audio.shape: (185661, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_016_007.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (117, 3)
# sample_audio.shape: (171990, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_016_008.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (116, 3)
# sample_audio.shape: (171108, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_016_009.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (48, 3)
# sample_audio.shape: (74529, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_017_000.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (126, 3)
# sample_audio.shape: (185661, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_017_001.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (117, 3)
# sample_audio.shape: (173313, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_017_002.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (117, 3)
# sample_audio.shape: (171990, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_017_003.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (126, 3)
# sample_audio.shape: (185661, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_017_004.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (117, 3)
# sample_audio.shape: (171990, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_017_005.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (117, 3)
# sample_audio.shape: (171990, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_017_006.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (126, 3)
# sample_audio.shape: (185661, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_017_007.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (117, 3)
# sample_audio.shape: (171990, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_017_008.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (116, 3)
# sample_audio.shape: (171108, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_017_009.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (126, 3)
# sample_audio.shape: (185661, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_017_010.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (117, 3)
# sample_audio.shape: (171990, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_017_011.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (31, 3)
# sample_audio.shape: (49833, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_018_000.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (126, 3)
# sample_audio.shape: (185661, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_018_001.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (117, 3)
# sample_audio.shape: (171990, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_018_002.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (117, 3)
# sample_audio.shape: (173313, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_018_003.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (126, 3)
# sample_audio.shape: (185661, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_018_004.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (117, 3)
# sample_audio.shape: (171990, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_018_005.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (117, 3)
# sample_audio.shape: (171990, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_018_006.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (126, 3)
# sample_audio.shape: (185661, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_018_007.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (117, 3)
# sample_audio.shape: (171990, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_018_008.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (81, 3)
# sample_audio.shape: (124362, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_019_000.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (126, 3)
# sample_audio.shape: (185661, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_019_001.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (117, 3)
# sample_audio.shape: (171990, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_019_002.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (117, 3)
# sample_audio.shape: (171990, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_019_003.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (126, 3)
# sample_audio.shape: (185661, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_019_004.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (117, 3)
# sample_audio.shape: (171990, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_019_005.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (117, 3)
# sample_audio.shape: (171990, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_019_006.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (126, 3)
# sample_audio.shape: (185661, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_019_007.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (117, 3)
# sample_audio.shape: (173313, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_019_008.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (116, 3)
# sample_audio.shape: (170667, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_019_009.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (33, 3)
# sample_audio.shape: (52920, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_020_000.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (126, 3)
# sample_audio.shape: (185661, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_020_001.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (117, 3)
# sample_audio.shape: (171990, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_020_002.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (117, 3)
# sample_audio.shape: (171990, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_020_003.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (3, 3)
# sample_audio.shape: (8820, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_021_000.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (126, 3)
# sample_audio.shape: (185661, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_021_001.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (117, 3)
# sample_audio.shape: (171990, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_021_002.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (117, 3)
# sample_audio.shape: (171990, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_021_003.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (126, 3)
# sample_audio.shape: (185661, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_021_004.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (81, 3)
# sample_audio.shape: (123479, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_022_000.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (126, 3)
# sample_audio.shape: (185661, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_022_001.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (117, 3)
# sample_audio.shape: (171990, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_022_002.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (117, 3)
# sample_audio.shape: (171990, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_022_003.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (126, 3)
# sample_audio.shape: (185661, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_022_004.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (117, 3)
# sample_audio.shape: (171990, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_022_005.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (117, 3)
# sample_audio.shape: (171990, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_022_006.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (126, 3)
# sample_audio.shape: (185661, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_022_007.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: (117, 3)
# sample_audio.shape: (173313, 2)
#
# ----------------------
# Video Capture Path: data/Video_chunks/Video_chunks\trial_lie_022_008.mp4
# Saved with shape:
# class_label_npy.shape: (1,)
# sample_coordinates_data.shape: